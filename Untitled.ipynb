# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pie chart:

# %%
plt.figure(figsize =(7,7))

x10 = [35,25,20,10,5]

labels = ['computer', 'electronics' , 'mecanicals' ,'chemical', 'instruments']

plt.pie(x10, labels = labels);

plt.show()

# %%
plt.figure(figsize =(7,7))

x10 = [35,25,20,10,5]

labels = ['computer', 'electronics' , 'mecanicals' ,'chemical', 'instruments']
 
plt.pie(x10, labels = labels , autopct = '%.2f');

plt.show()
