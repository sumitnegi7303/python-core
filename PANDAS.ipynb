# %% [markdown]
# ## Reading Different datasets in pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# csv = coma seperated values

# %%
data = pd.read_csv("ex1.csv")
data
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
a = pd.read_csv("ex1.csv")
a
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
b = pd.read_csv("ex2.csv")
b
# Out:
#    1   2   3   4  hello
# 0  5   6   7   8  world
# 1  9  10  11  12    foo

# %%
c = pd.read_csv("ex3.csv")
c
# Out:
#                A         B         C
# 0  aaa -0.264438 -1.026059 -0.619500
# 1  bbb  0.927272  0.302904 -0.032399
# 2  ccc -0.264273 -0.386314 -0.217601
# 3  ddd -0.871858 -0.348382  1.100491

# %% [markdown]
# more then 1 coumn are called frame
#
# single column are called series

# %%
type(data["a"])
# Out:
# pandas.core.series.Series

# %%
data["message"]
# Out:
# 0    hello
# 1    world
# 2      foo
# Name: message, dtype: object

# %%
data[["message","a"]]
# Out:
#   message  a
# 0   hello  1
# 1   world  5
# 2     foo  9

# %%
data[["message","a","c"]]
# Out:
#   message  a   c
# 0   hello  1   3
# 1   world  5   7
# 2     foo  9  11

# %%
data = pd.read_csv("ex2.csv")
data
# Out:
#    1   2   3   4  hello
# 0  5   6   7   8  world
# 1  9  10  11  12    foo

# %%
d2 = pd.read_csv("ex2.csv",header = None,names = ["a","b","c","d","e"])
d2
# Out:
#    a   b   c   d      e
# 0  1   2   3   4  hello
# 1  5   6   7   8  world
# 2  9  10  11  12    foo

# %%
d3 = pd.read_csv("ex3.csv")
d3
# Out:
#                A         B         C
# 0  aaa -0.264438 -1.026059 -0.619500
# 1  bbb  0.927272  0.302904 -0.032399
# 2  ccc -0.264273 -0.386314 -0.217601
# 3  ddd -0.871858 -0.348382  1.100491

# %%
d4 = pd.read_csv("ex4.csv")
d4                                                  #NaN means missing value :
# Out:
#                                                                       # hey!
# a                                                  b        c   d    message
# # just wanted to make things more difficult for... NaN      NaN NaN      NaN
# # who reads CSV files with computers                anyway? NaN NaN      NaN
# 1                                                  2        3   4      hello
# 5                                                  6        7   8      world
# 9                                                  10       11  12       foo

# %%
d4 = pd.read_csv("ex4.csv",skiprows = [0,2,3])       #skiprows is used to skip the rows or the null value in the data.
d4
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
d5 = pd.read_excel('C:\\Users\\GOURAV NEGI\\OneDrive\\Documents\\book1.xlsx',sheet_name = "Sheet1",engine = "openpyxl")
d5
# Out:
#     Anurag  23
# 0    mohit  45
# 1    sumit  34
# 2    komal  24
# 3  akansha  66
# 4     nivi  56
# 5  anushka  46
# 6    lisha  34
# 7   jennie  35

# %%
d5 = pd.read_excel('C:\\Users\\GOURAV NEGI\\OneDrive\\Documents\\book1.xlsx')
d5
# Out:
#     Anurag  23
# 0    mohit  45
# 1    sumit  34
# 2    komal  24
# 3  akansha  66
# 4     nivi  56
# 5  anushka  46
# 6    lisha  34
# 7   jennie  35

# %%
d6 = pd.read_csv("ex5.csv")
d6
# Out:
#   something  a   b    c   d message
# 0       one  1   2  3.0   4     NaN
# 1       two  5   6  NaN   8   world
# 2     three  9  10  NaN  12     foo

# %%
d6.isnull()
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False   True  False    False

# %%
True = 1         #true is always 1
False = 0        #false is always 0

# %%
d6.isnull().sum()
# Out:
# something    0
# a            0
# b            0
# c            2
# d            0
# message      1
# dtype: int64

# %%
d7 = pd.read_csv("ex6.csv")
d7
# Out:
#            one       two     three      four key
# 0     0.467976 -0.038649 -0.295344 -1.824726   L
# 1    -0.358893  1.404453  0.704965 -0.200638   B
# 2    -0.501840  0.659254 -0.421691 -0.057688   G
# 3     0.204886  1.074134  1.388361 -0.982404   R
# 4     0.354628 -0.133116  0.283763 -0.837063   Q
# ...        ...       ...       ...       ...  ..
# 9995  2.311896 -0.417070 -1.409599 -0.515821   L
# 9996 -0.479893 -0.650419  0.745152 -0.646038   E
# 9997  0.523331  0.787112  0.486066  1.093156   K
# 9998 -0.362559  0.598894 -1.843201  0.887292   G
# 9999 -0.096376 -1.012999 -0.657431 -0.573315   0
#
# [10000 rows x 5 columns]

# %%
# iterables = in which we can conduct loop
# iterator = lazy value (it is used to fetch one by one value)

# %%
l = [1,2,3]
a=iter(l)
a

# %%
next(a)
# Out:
# 1

# %%
next(a)
# Out:
# 2

# %%
next(a)
# Out:
# 3

# %%
d7 = pd.read_csv("ex6.csv",iterator = True ,chunksize = 1000)
d7

# %%
data0_999 = next(d7)
data0_999
# Out:
#           one       two     three      four key
# 0    0.467976 -0.038649 -0.295344 -1.824726   L
# 1   -0.358893  1.404453  0.704965 -0.200638   B
# 2   -0.501840  0.659254 -0.421691 -0.057688   G
# 3    0.204886  1.074134  1.388361 -0.982404   R
# 4    0.354628 -0.133116  0.283763 -0.837063   Q
# ..        ...       ...       ...       ...  ..
# 995  2.311896 -0.417070 -1.409599 -0.515821   M
# 996 -0.479893 -0.650419  0.745152 -0.646038   H
# 997  0.523331  0.787112  0.486066  1.093156   D
# 998 -0.362559  0.598894 -1.843201  0.887292   W
# 999 -0.096376 -1.012999 -0.657431 -0.573315   K
#
# [1000 rows x 5 columns]

# %%
d8 = pd.read_csv("ex7.csv")
d8
# Out:
#    a  b  c
# 0  1  2  3
# 1  1  2  3
# 2  4  5  6

# %%
d8["d"] = [67,12,89]

# %%
d8
# Out:
#    a  b  c   d
# 0  1  2  3  67
# 1  1  2  3  12
# 2  4  5  6  89

# %%
d9 = pd.read_table("test.tsv")
d9
# Out:
#         test   test test.1 test.2 test.3
# sudh    sudh   sudh   sudh   sudh   sudh
# kumar  kumar  kumar  kumar  kumar  kumar

# %%
d10 = pd.read_table("ex1.csv",sep = ",")
d10
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
d11 = pd.read_table("ex1.csv")
d11
# Out:
#   a,b,c,d,message
# 0   1,2,3,4,hello
# 1   5,6,7,8,world
# 2  9,10,11,12,foo

# %%
d12 = pd.read_table("tseries.csv")
d12
# Out:
#              ,0
# 0  2000-01-01,0
# 1  2000-01-02,1
# 2  2000-01-03,2
# 3  2000-01-04,3
# 4  2000-01-05,4
# 5  2000-01-06,5
# 6  2000-01-07,6

# %%
d11= pd.read_csv("tseries.csv",index_col = [0])
d11
# Out:
#             0
# 2000-01-01  0
# 2000-01-02  1
# 2000-01-03  2
# 2000-01-04  3
# 2000-01-05  4
# 2000-01-06  5
# 2000-01-07  6

# %%
d11= pd.read_csv("tseries.csv",index_col = [1])
d11
# Out:
#    Unnamed: 0
# 0
# 0  2000-01-01
# 1  2000-01-02
# 2  2000-01-03
# 3  2000-01-04
# 4  2000-01-05
# 5  2000-01-06
# 6  2000-01-07

# %%
d11.rename(columns = {"0":"value"},inplace = True)

# %%
d11
# Out:
#             value
# 2000-01-01      0
# 2000-01-02      1
# 2000-01-03      2
# 2000-01-04      3
# 2000-01-05      4
# 2000-01-06      5
# 2000-01-07      6

# %%
d12 = pd.read_html("https://www.espn.com/soccer/standings/_/league/eng.1")            #html for site data only
d12
# Out:
# [                       2021-2022
#  0            1MNCManchester City
#  1                  2LIVLiverpool
#  2                    3CHEChelsea
#  3          4TOTTottenham Hotspur
#  4                    5ARSArsenal
#  5          6MANManchester United
#  6            7WHUWest Ham United
#  7             8LEILeicester City
#  8     9BHABrighton & Hove Albion
#  9   10WOLWolverhampton Wanderers
#  10         11NEWNewcastle United
#  11           12CRYCrystal Palace
#  12                13BREBrentford
#  13              14AVLAston Villa
#  14              15SOUSouthampton
#  15                  16EVEEverton
#  16             17LEELeeds United
#  17                  18BURBurnley
#  18                  19WATWatford
#  19             20NORNorwich City,
#      GP   W   D   L   F   A  GD   P
#  0   38  29   6   3  99  26  73  93
#  1   38  28   8   2  94  26  68  92
#  2   38  21  11   6  76  33  43  74
#  3   38  22   5  11  69  40  29  71
#  4   38  22   3  13  61  48  13  69
# ...

# %%
d12[0]
# Out:
#                        2021-2022
# 0            1MNCManchester City
# 1                  2LIVLiverpool
# 2                    3CHEChelsea
# 3          4TOTTottenham Hotspur
# 4                    5ARSArsenal
# 5          6MANManchester United
# 6            7WHUWest Ham United
# 7             8LEILeicester City
# 8     9BHABrighton & Hove Albion
# 9   10WOLWolverhampton Wanderers
# 10         11NEWNewcastle United
# 11           12CRYCrystal Palace
# 12                13BREBrentford
# 13              14AVLAston Villa
# 14              15SOUSouthampton
# 15                  16EVEEverton
# 16             17LEELeeds United
# 17                  18BURBurnley
# 18                  19WATWatford
# 19             20NORNorwich City

# %%
d12[1]
# Out:
#     GP   W   D   L   F   A  GD   P
# 0   38  29   6   3  99  26  73  93
# 1   38  28   8   2  94  26  68  92
# 2   38  21  11   6  76  33  43  74
# 3   38  22   5  11  69  40  29  71
# 4   38  22   3  13  61  48  13  69
# 5   38  16  10  12  57  57   0  58
# 6   38  16   8  14  60  51   9  56
# 7   38  14  10  14  62  59   3  52
# 8   38  12  15  11  42  44  -2  51
# 9   38  15   6  17  38  43  -5  51
# 10  38  13  10  15  44  62 -18  49
# 11  38  11  15  12  50  46   4  48
# 12  38  13   7  18  48  56  -8  46
# 13  38  13   6  19  52  54  -2  45
# 14  38   9  13  16  43  67 -24  40
# 15  38  11   6  21  43  66 -23  39
# 16  38   9  11  18  42  79 -37  38
# 17  38   7  14  17  34  53 -19  35
# 18  38   6   5  27  34  77 -43  23
# 19  38   5   7  26  23  84 -61  22

# %%
d13 = pd.read_csv("https://gist.githubusercontent.com/fyyying/4aa5b471860321d7b47fd881898162b7/raw/6907bb3a38bfbb6fccf3a8b1edfb90e39714d14f/titanic_dataset.csv")
d13
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
d14 = pd.read_html("fdic_failed_bank_list.html")
d14
# Out:
# [                             Bank Name             City  ST   CERT  \
#  0                          Allied Bank         Mulberry  AR     91
#  1         The Woodbury Banking Company         Woodbury  GA  11297
#  2               First CornerStone Bank  King of Prussia  PA  35312
#  3                   Trust Company Bank          Memphis  TN   9956
#  4           North Milwaukee State Bank        Milwaukee  WI  20364
#  ..                                 ...              ...  ..    ...
#  542                 Superior Bank, FSB         Hinsdale  IL  32646
#  543                Malta National Bank            Malta  OH   6629
#  544    First Alliance Bank & Trust Co.       Manchester  NH  34264
#  545  National State Bank of Metropolis       Metropolis  IL   3815
#  546                   Bank of Honolulu         Honolulu  HI  21029
#
#                     Acquiring Institution        Closing Date  \
#  0                           Today's Bank  September 23, 2016
# ...

# %%
d14[0]
# Out:
#                              Bank Name             City  ST   CERT  \
# 0                          Allied Bank         Mulberry  AR     91
# 1         The Woodbury Banking Company         Woodbury  GA  11297
# 2               First CornerStone Bank  King of Prussia  PA  35312
# 3                   Trust Company Bank          Memphis  TN   9956
# 4           North Milwaukee State Bank        Milwaukee  WI  20364
# ..                                 ...              ...  ..    ...
# 542                 Superior Bank, FSB         Hinsdale  IL  32646
# 543                Malta National Bank            Malta  OH   6629
# 544    First Alliance Bank & Trust Co.       Manchester  NH  34264
# 545  National State Bank of Metropolis       Metropolis  IL   3815
# 546                   Bank of Honolulu         Honolulu  HI  21029
#
#                    Acquiring Institution        Closing Date  \
# 0                           Today's Bank  September 23, 2016
# ...

# %%
type(d14[0])
# Out:
# pandas.core.frame.DataFrame

# %%
e = pd.read_csv("stock_px.csv")
e
# Out:
#                Unnamed: 0     AA    AAPL     GE     IBM    JNJ   MSFT    PEP  \
# 0     1990-02-01 00:00:00   4.98    7.86   2.87   16.79   4.27   0.51   6.04
# 1     1990-02-02 00:00:00   5.04    8.00   2.87   16.89   4.37   0.51   6.09
# 2     1990-02-05 00:00:00   5.07    8.18   2.87   17.32   4.34   0.51   6.05
# 3     1990-02-06 00:00:00   5.01    8.12   2.88   17.56   4.32   0.51   6.15
# 4     1990-02-07 00:00:00   5.04    7.77   2.91   17.93   4.38   0.51   6.17
# ...                   ...    ...     ...    ...     ...    ...    ...    ...
# 5467  2011-10-10 00:00:00  10.09  388.81  16.14  186.62  64.43  26.94  61.87
# 5468  2011-10-11 00:00:00  10.30  400.29  16.14  185.00  63.96  27.00  60.95
# 5469  2011-10-12 00:00:00  10.05  402.19  16.40  186.12  64.33  26.96  62.70
# 5470  2011-10-13 00:00:00  10.10  408.43  16.22  186.82  64.23  27.18  62.36
# 5471  2011-10-14 00:00:00  10.26  422.00  16.60  190.53  64.72  27.27  62.24
#
#           SPX    XOM
# 0      328.79   6.12
# ...

# %%
f = pd.read_csv("C:\\Users\\GOURAV NEGI\\Downloads\\amazon.csv",encoding = "Iso-8859-1")
f                                                         #this encoding is when you didn't allow acces to do this code ,
# Out:
#       year      state     month  number        date
# 0     1998       Acre   Janeiro     0.0  1998-01-01
# 1     1999       Acre   Janeiro     0.0  1999-01-01
# 2     2000       Acre   Janeiro     0.0  2000-01-01
# 3     2001       Acre   Janeiro     0.0  2001-01-01
# 4     2002       Acre   Janeiro     0.0  2002-01-01
# ...    ...        ...       ...     ...         ...
# 6449  2012  Tocantins  Dezembro   128.0  2012-01-01
# 6450  2013  Tocantins  Dezembro    85.0  2013-01-01
# 6451  2014  Tocantins  Dezembro   223.0  2014-01-01
# 6452  2015  Tocantins  Dezembro   373.0  2015-01-01
# 6453  2016  Tocantins  Dezembro   119.0  2016-01-01
#
# [6454 rows x 5 columns]

# %% [markdown]
# # DATA cleaning

# %%
#creating a data frame from a dictionery

# %%
df = pd.DataFrame({"age":[12,13,14,15],"height":[120,123,145,136],"weight":[56,78,87,90]})
df
# Out:
#    age  height  weight
# 0   12     120      56
# 1   13     123      78
# 2   14     145      87
# 3   15     136      90

# %%
df.head(2)                            # it will read 2 uper  values :
# Out:
#    age  height  weight
# 0   12     120      56
# 1   13     123      78

# %%
df.head()                              # by default it will be give a  top 5 values is give
# Out:
#    age  height  weight
# 0   12     120      56
# 1   13     123      78
# 2   14     145      87
# 3   15     136      90

# %%
df.tail(2)                # it will read downward rows
# Out:
#    age  height  weight
# 2   14     145      87
# 3   15     136      90

# %%
df.shape           #it will give a rows and columns
# Out:
# (4, 3)

# %%
df.shape[0]     #it will tell us rows and columns by indexing
# Out:
# 4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     4 non-null      int64
#  1   height  4 non-null      int64
#  2   weight  4 non-null      int64
# dtypes: int64(3)
# memory usage: 224.0 bytes

# %%
df.describe()
# Out:
#              age      height     weight
# count   4.000000    4.000000   4.000000
# mean   13.500000  131.000000  77.750000
# std     1.290994   11.633286  15.370426
# min    12.000000  120.000000  56.000000
# 25%    12.750000  122.250000  72.500000
# 50%    13.500000  129.500000  82.500000
# 75%    14.250000  138.250000  87.750000
# max    15.000000  145.000000  90.000000

# %%
df.describe().T             #it covert colums to rows & rows to  columns transpose
# Out:
#         count    mean        std    min     25%    50%     75%    max
# age       4.0   13.50   1.290994   12.0   12.75   13.5   14.25   15.0
# height    4.0  131.00  11.633286  120.0  122.25  129.5  138.25  145.0
# weight    4.0   77.75  15.370426   56.0   72.50   82.5   87.75   90.0

# %%
import seaborn as sns

# %%
df1 = sns.load_dataset("titanic")

# %%
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df1.isnull()            #isnull mean find the missing value
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
df1.isnull().sum()
                            #isna is same isnull.
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
(df1.isnull().sum()/df1.shape[0])*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df1.shape
# Out:
# (891, 15)

# %%
df1["age"].mean()
# Out:
# 29.69911764705882

# %%
df1["age"].median()
# Out:
# 28.0

# %%
df1.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df1["age"].fillna(df1["age"].median(),inplace = True)

# %%
#fillna is fill the missing value

# %%
df1["age"].isna().sum()
# Out:
# 0

# %%
df1["embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df1["embarked"].mode()
# Out:
# 0    S
# dtype: object

# %%
df1["embarked"].fillna(df1["embarked"].mode()[0],inplace = True)

# %%
df1.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df1["embarked"].value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: embarked, dtype: int64

# %%
df1["survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
df1["survived"].nunique()
# Out:
# 2

# %%
df1["survived"].count()
# Out:
# 891

# %%
(df1["survived"].value_counts()/df1["survived"].count())*100
# Out:
# 0    61.616162
# 1    38.383838
# Name: survived, dtype: float64

# %%
from scipy import stats                           # statistics use mathmaticks ka lia

# %%
import matplotlib.pyplot as plt                      #  visualization

# %%
plt.boxplot(df1["fare"]);

# %%
iqr = stats.iqr(df1["fare"])
iqr                                              #iqr is interqurtile range hoti hai (q3-q1)
                                                       #  quartile uper- Q3 & lower quartile-q1
# Out:
# 23.0896

# %%
df1["fare"].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64

# %%
a=31+1.5*iqr
a
# Out:
# 65.6344

# %%
len(df1[df1["fare"]>a])
# Out:
# 116

# %%
import numpy as np

# %%
np.percentile(df1["age"],[0.10,0.25,0.50,0.75,0.90,0.99])
# Out:
# array([nan, nan, nan, nan, nan, nan])

# %%
np.percentile(df1["fare"],[0,10,25,50,75,90,99,100])
# Out:
# array([  0.     ,   7.55   ,   7.9104 ,  14.4542 ,  31.     ,  77.9583 ,
#        249.00622, 512.3292 ])

# %%
np.quantile(df1["age"],[0,0.10,0.25,0.50,0.75,0.90,0.99,0.999,1.0])
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan])

# %%
df1.drop(columns = ["deck","embark_town"],inplace = True)      #how to drop column

# %%
df1.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'alive', 'alone'],
#       dtype='object')

# %%
#indexing and slicing in dataframe

# %%
#iloc, loc
#iloc - indexs are numbers
#loc = named indexes

# %%
df1.iloc[50:101,2:7]
# Out:
#         sex    age  sibsp  parch      fare
# 50     male   7.00      4      1   39.6875
# 51     male  21.00      0      0    7.8000
# 52   female  49.00      1      0   76.7292
# 53   female  29.00      1      0   26.0000
# 54     male  65.00      0      1   61.9792
# 55     male    NaN      0      0   35.5000
# 56   female  21.00      0      0   10.5000
# 57     male  28.50      0      0    7.2292
# 58   female   5.00      1      2   27.7500
# 59     male  11.00      5      2   46.9000
# 60     male  22.00      0      0    7.2292
# 61   female  38.00      0      0   80.0000
# 62     male  45.00      1      0   83.4750
# 63     male   4.00      3      2   27.9000
# 64     male    NaN      0      0   27.7208
# 65     male    NaN      1      1   15.2458
# 66   female  29.00      0      0   10.5000
# 67     male  19.00      0      0    8.1583
# 68   female  17.00      4      2    7.9250
# 69     male  26.00      2      0    8.6625
# 70     male  32.00      0      0   10.5000
# ...

# %%
import pandas as pd

# %%
df2 = pd.DataFrame({"marks":[33,45,56,67]},index = ["golu","molu","bholu","neha"])
df2.loc[["golu","neha"]]
# Out:
#       marks
# golu     33
# neha     67

# %%
df2.loc["golu":"neha"]
# Out:
#        marks
# golu      33
# molu      45
# bholu     56
# neha      67

# %%
import numpy as np
import pandas as pd

# %%
a = np.array([1,2,3,4,4])
a
# Out:
# array([1, 2, 3, 4, 4])

# %%
col = pd.Series(a)
type(col)
# Out:
# pandas.core.series.Series

# %%
df = pd.DataFrame(col,columns=["col1"])

# %%
df
# Out:
#    col1
# 0     1
# 1     2
# 2     3
# 3     4
# 4     4

# %%
df["col2"] = [10,11,12,13,14]

# %%
df
# Out:
#    col1  col2
# 0     1    10
# 1     2    11
# 2     3    12
# 3     4    13
# 4     4    14

# %%
#condition in dataframes

# %%
df1[df1["sex"]=="male"]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df1[(df1["sex"]=="male") & (df1["alive"]=="yes")]["class"].value_counts()
# Out:
# Third     47
# First     45
# Second    17
# Name: class, dtype: int64

# %%
df1[(df1["sex"]=="male") & (df1["alive"]=="yes")][["class","fare","age"]].value_counts()
# Out:
# class   fare     age
# Third   56.4958  32.00    2
#         7.2250   22.00    1
#         7.9250   31.00    1
#                  20.00    1
#         7.8958   29.00    1
#                          ..
# First   79.2000  60.00    1
#         76.7292  48.00    1
#                  27.00    1
#         63.3583  23.00    1
# Second  18.7500  0.83     1
# Length: 92, dtype: int64

# %%
df1[(df1["sex"]=="female") & (df1["alive"]=="yes")][["fare"]].value_counts()
# Out:
# fare
# 26.0000     12
# 13.0000     12
# 7.7500      10
# 10.5000      7
# 7.8792       4
#             ..
# 18.7500      1
# 17.4000      1
# 16.0000      1
# 15.7500      1
# 512.3292     1
# Length: 128, dtype: int64

# %%
df1[(df1["age"]<18)]["survived"].value_counts()
# Out:
# 1    61
# 0    52
# Name: survived, dtype: int64

# %% [markdown]
# # pandas class 5

# %%
#Aggregation                       #adding group adding

# %%
import numpy as np
import pandas as pd
import seaborn as sns               #visualization data visualization karte h

# %%
df3 = sns.load_dataset("diamonds")

# %%
df3
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df3.groupby("cut",)["price"].mean()                     #mean()means  middle value of price
# Out:
# cut
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Good         3928.864452
# Fair         4358.757764
# Name: price, dtype: float64

# %%
df3.groupby(["cut","clarity"])["price"].mean()
# Out:
# cut        clarity
# Ideal      IF         2272.913366
#            VVS1       2468.129458
#            VVS2       3250.290100
#            VS1        3489.744497
#            VS2        3284.550385
#            SI1        3752.118169
#            SI2        4755.952656
#            I1         4335.726027
# Premium    IF         3856.143478
#            VVS1       2831.206169
#            VVS2       3795.122989
#            VS1        4485.462041
#            VS2        4550.331248
#            SI1        4455.269371
#            SI2        5545.936928
#            I1         3947.331707
# Very Good  IF         4396.216418
#            VVS1       2459.441065
#            VVS2       3037.765182
#            VS1        3805.353239
#            VS2        4215.759552
#            SI1        3932.391049
#            SI2        4988.688095
#            I1         4078.226190
# Good       IF         4098.323944
#            VVS1       2254.774194
#            VVS2       3079.108392
# ...

# %%
df3["color"].unique()
# Out:
# ['E', 'I', 'J', 'H', 'F', 'G', 'D']
# Categories (7, object): ['D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
df3.groupby("cut")["color"].value_counts()
# Out:
# cut
# Ideal      G    4884
#            E    3903
#            F    3826
#            H    3115
#            D    2834
#            I    2093
#            J     896
# Premium    G    2924
#            H    2360
#            E    2337
#            F    2331
#            D    1603
#            I    1428
#            J     808
# Very Good  E    2400
#            G    2299
#            F    2164
#            H    1824
#            D    1513
#            I    1204
#            J     678
# Good       E     933
#            F     909
#            G     871
#            H     702
#            D     662
#            I     522
#            J     307
# Fair       G     314
#            F     312
#            H     303
#            E     224
#            I     175
#            D     163
#            J     119
# Name: color, dtype: int64

# %%
df1.groupby(["pclass","sex"])["survived"].value_counts()
# Out:
# pclass  sex     survived
# 1       female  1            91
#                 0             3
#         male    0            77
#                 1            45
# 2       female  1            70
#                 0             6
#         male    0            91
#                 1            17
# 3       female  0            72
#                 1            72
#         male    0           300
#                 1            47
# Name: survived, dtype: int64

# %%
df1.groupby(["pclass","sex"])["survived"].count()                #count it gives count all the
# Out:
# pclass  sex
# 1       female     94
#         male      122
# 2       female     76
#         male      108
# 3       female    144
#         male      347
# Name: survived, dtype: int64

# %%
(df1.groupby(["pclass","sex"])["survived"].value_counts()/a)*100             # %nikali hai
# Out:
# pclass  sex     survived
# 1       female  1           96.808511
#                 0            3.191489
#         male    0           63.114754
#                 1           36.885246
# 2       female  1           92.105263
#                 0            7.894737
#         male    0           84.259259
#                 1           15.740741
# 3       female  0           50.000000
#                 1           50.000000
#         male    0           86.455331
#                 1           13.544669
# Name: survived, dtype: float64

# %%
df1.groupby(["pclass","sex"])["fare"].max()
# Out:
# pclass  sex
# 1       female    512.3292
#         male      512.3292
# 2       female     65.0000
#         male       73.5000
# 3       female     69.5500
#         male       69.5500
# Name: fare, dtype: float64

# %%
df1.groupby(["pclass","sex"])["fare"].min()
# Out:
# pclass  sex
# 1       female    25.9292
#         male       0.0000
# 2       female    10.5000
#         male       0.0000
# 3       female     6.7500
#         male       0.0000
# Name: fare, dtype: float64

# %%
df1.groupby(["pclass","sex"])["fare"].agg(["min","max","mean","median","std","var"])
# Out:
#                    min       max        mean    median        std          var
# pclass sex
# 1      female  25.9292  512.3292  106.125798  82.66455  74.259988  5514.545830
#        male     0.0000  512.3292   67.226127  41.26250  77.548021  6013.695545
# 2      female  10.5000   65.0000   21.970121  22.00000  10.891796   118.631214
#        male     0.0000   73.5000   19.741782  13.00000  14.922235   222.673090
# 3      female   6.7500   69.5500   16.118810  12.47500  11.690314   136.663446
#        male     0.0000   69.5500   12.661633   7.92500  11.681696   136.462010

# %%
df1.groupby(["pclass","survived"])["fare"].agg(["min","max","mean","median","std","var"])
# Out:
#                      min       max       mean   median        std          var
# pclass survived
# 1      0          0.0000  263.0000  64.684007  44.7500  60.662089  3679.889076
#        1         25.9292  512.3292  95.608029  77.9583  85.286820  7273.841710
# 2      0          0.0000   73.5000  19.412328  13.0000  15.307175   234.309611
#        1         10.5000   65.0000  22.055700  21.0000  10.853502   117.798505
# 3      0          0.0000   69.5500  13.669364   8.0500  12.118338   146.854107
#        1          0.0000   56.4958  13.694887   8.5167  10.692993   114.340104

# %%
#np.where                        # condition use kai lia

# %%
df1.loc[np.where(df1["fare"]>100)]
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked  class  \
# 27          0       1    male  19.00      3      2  263.0000        S  First
# 31          1       1  female    NaN      1      0  146.5208        C  First
# 88          1       1  female  23.00      3      2  263.0000        S  First
# 118         0       1    male  24.00      0      1  247.5208        C  First
# 195         1       1  female  58.00      0      0  146.5208        C  First
# 215         1       1  female  31.00      1      0  113.2750        C  First
# 258         1       1  female  35.00      0      0  512.3292        C  First
# 268         1       1  female  58.00      0      1  153.4625        S  First
# 269         1       1  female  35.00      0      0  135.6333        S  First
# 297         0       1  female   2.00      1      2  151.5500        S  First
# 299         1       1  female  50.00      0      1  247.5208        C  First
# ...

# %%
#iloc will slice with numbers 
#loc will slice with names 
#both are same but this and that

# %%
df1.sort_values(by = "fare",ascending = False).head(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 88          1       1  female  23.0      3      2  263.0000        S  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
# 341         1       1  female  24.0      3      2  263.0000        S  First
# 438         0       1    male  64.0      1      4  263.0000        S  First
# 311         1       1  female  18.0      2      2  262.3750        C  First
# 742         1       1  female  21.0      2      2  262.3750        C  First
# 118         0       1    male  24.0      0      1  247.5208        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 258  woman       False  NaN    Cherbourg   yes   True
# ...

# %%
df4 = sns.load_dataset("tips")

# %%
df4
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df4["total"]=df4["total_bill"]+df4["tip"]

# %%
df4
# Out:
#      total_bill   tip     sex smoker   day    time  size    new
# 0         16.99  1.01  Female     No   Sun  Dinner     2  18.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3  12.00
# 2         21.01  3.50    Male     No   Sun  Dinner     3  24.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2  26.99
# 4         24.59  3.61  Female     No   Sun  Dinner     4  28.20
# ..          ...   ...     ...    ...   ...     ...   ...    ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  34.95
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  29.18
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  24.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2  19.57
# 243       18.78  3.00  Female     No  Thur  Dinner     2  21.78
#
# [244 rows x 8 columns]

# %%
#lambda
#what is lambda, lambda is a key word to create a anonymous function

# %%
a = lambda pi,r:4/3*pi*r**3
a(3.14,10)
# Out:
# 4186.666666666667

# %%
df4["log_bill"] = df4["total_bill"].apply(lambda x : np.log(x))
df4
# Out:
#      total_bill   tip     sex smoker   day    time  size    new  total  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2  18.00  18.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3  12.00  12.00
# 2         21.01  3.50    Male     No   Sun  Dinner     3  24.51  24.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2  26.99  26.99
# 4         24.59  3.61  Female     No   Sun  Dinner     4  28.20  28.20
# ..          ...   ...     ...    ...   ...     ...   ...    ...    ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  34.95  34.95
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  29.18  29.18
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  24.67  24.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2  19.57  19.57
# 243       18.78  3.00  Female     No  Thur  Dinner     2  21.78  21.78
#
#      log_bill
# 0    2.832625
# 1    2.336020
# 2    3.044999
# 3    3.164631
# 4    3.202340
# ..        ...
# ...

# %%
define a function using a lamda which convert farenget to celcious an

# %%
#convert celcious to farhanite
b = lambda f:(f-32)/1.8
b(75)
# Out:
# 23.88888888888889

# %%
#convert farhanite to celcious
c = lambda c:(c*1.8)+32
c(55)
# Out:
# 131.0

# %% [markdown]
# # class6

# %%
import numpy as np
import pandas as pd
import seaborn as snp

# %%
# map and replace

# %%
#label encoding
#one hot encoding

# %%
#label encoding : ordinal : categories in order
#one hot encoding : normal : catogories not in order

# %%
df4 = sns.load_dataset("tips")
df4
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df4["sex"]
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# Name: sex, Length: 244, dtype: category
# Categories (2, object): ['Male', 'Female']

# %%
df4["time"].replace({"dinner":1,"lunch":0},inplace = True)

# %%
df4["time"].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
df4["smoker"]
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#       ...
# 239     No
# 240    Yes
# 241    Yes
# 242     No
# 243     No
# Name: smoker, Length: 244, dtype: category
# Categories (2, object): ['Yes', 'No']

# %%
import seaborn as sns

# %%
df4 = sns.load_dataset("tips")

# %%
df4['smoker']=df4['smoker'].map({"no":0,"yes":1})

# %%
df4['smoker']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 239   NaN
# 240   NaN
# 241   NaN
# 242   NaN
# 243   NaN
# Name: smoker, Length: 244, dtype: float64

# %%
#one hot encoding

# %%
df4["day"].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
x = pd.get_dummies(df4["day"],drop_first = True)

# %%
x
# Out:
#      Fri  Sat  Sun
# 0      0    0    1
# 1      0    0    1
# 2      0    0    1
# 3      0    0    1
# 4      0    0    1
# ..   ...  ...  ...
# 239    0    1    0
# 240    0    1    0
# 241    0    1    0
# 242    0    1    0
# 243    0    0    0
#
# [244 rows x 3 columns]

# %%
df4 = sns.load_dataset("tips")

# %%
df4 = pd.concat([df4,x],axis = 1)

# %%
df4
# Out:
#      total_bill   tip     sex smoker   day    time  size  Fri  Sat  Sun
# 0         16.99  1.01  Female     No   Sun  Dinner     2    0    0    1
# 1         10.34  1.66    Male     No   Sun  Dinner     3    0    0    1
# 2         21.01  3.50    Male     No   Sun  Dinner     3    0    0    1
# 3         23.68  3.31    Male     No   Sun  Dinner     2    0    0    1
# 4         24.59  3.61  Female     No   Sun  Dinner     4    0    0    1
# ..          ...   ...     ...    ...   ...     ...   ...  ...  ...  ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3    0    1    0
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    0    1    0
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    0    1    0
# 242       17.82  1.75    Male     No   Sat  Dinner     2    0    1    0
# 243       18.78  3.00  Female     No  Thur  Dinner     2    0    0    0
#
# [244 rows x 10 columns]

# %%
df = pd.DataFrame({"key":[1,12,3,4],"A":[5,6,7,8],"B":[9,10,11,12]})

# %%
df
# Out:
#    key  A   B
# 0    1  5   9
# 1   12  6  10
# 2    3  7  11
# 3    4  8  12

# %%
df2 = pd.DataFrame({"key":[1,2,3,5],"A":[500,600,700,800],"B":[900,1000,1100,1200]})

# %%
df2
# Out:
#    key    A     B
# 0    1  500   900
# 1    2  600  1000
# 2    3  700  1100
# 3    5  800  1200

# %%
pd.merge(df,df2,how = "outer", on = "key")
# Out:
#    key  A_x   B_x    A_y     B_y
# 0    1  5.0   9.0  500.0   900.0
# 1   12  6.0  10.0    NaN     NaN
# 2    3  7.0  11.0  700.0  1100.0
# 3    4  8.0  12.0    NaN     NaN
# 4    2  NaN   NaN  600.0  1000.0
# 5    5  NaN   NaN  800.0  1200.0

# %%
pd.merge(df,df2,how = "inner", on = "key")
# Out:
#    key  A_x  B_x  A_y   B_y
# 0    1    5    9  500   900
# 1    3    7   11  700  1100

# %% [markdown]
# # join method

# %%
df.join(df2,how = "inner",lsuffix = "x",rsuffix = "_y")
# Out:
#    keyx  Ax  Bx  key_y  A_y   B_y
# 0     1   5   9      1  500   900
# 1    12   6  10      2  600  1000
# 2     3   7  11      3  700  1100
# 3     4   8  12      5  800  1200

# %%
df.set_index("key",inplace = True)
df2.set_index("key",inplace = True)

# %%
df.join(df2,how = "right",lsffix = "_x",rsuffix = "_y")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\GOURAV~1\AppData\Local\Temp/ipykernel_19424/230248362.py in <module>
# ----> 1 df.join(df2,how = "right",lsffix = "_x",rsuffix = "_y")
#
# TypeError: join() got an unexpected keyword argument 'lsffix'
