# %%
seaborn : statistical data visualization library

# %%
3 types of sns :
    NUmerical plotting
    categorical
    Distributions

# %%
Numerical plot :
1) relplot
2) scatterplot
3) lineplot

categorical :
1)catplot
2)striplot
3)swarm
4)voilin
5)boxplot
6)boxen

Distribution :
1)distplot
2)jointplot
3)kdeplot

# %% [markdown]
# # numerical ploting :

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(style = 'darkgrid')

# %%
df = sns.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.relplot(x = "petal_length",y = "sepal_width",data = df);

# %%
sns.relplot(x = "petal_length",y = "sepal_width",data = df,hue = "species");

# %%
df = sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = "total_bill",y = "tip",data = df,hue = "sex");

# %%
sns.relplot(x = "total_bill",y = "tip",data = df,hue = "sex",size = "sex",style="smoker");

# %%
d = sns.load_dataset("titanic")
d.head(2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %%
sns.relplot(x ="age",y = "fare",data = d ,hue ="sex",size = "class",style ='alive');

# %%
sns.relplot(x ="age",y = "fare",data = d,col = "embarked");

# %%
sns.relplot(x ="age",y = "fare",data = d,col = "class");

# %%
sns.relplot(x ="age",y = "fare",data = d,col = "class",col_wrap=2);

# %%
df4 = sns.load_dataset("fmri")
df4
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x = "timepoint", y ="signal",data = df4,kind= "line",ci = False)

# %%
sns.relplot(x = "timepoint", y ="signal",data = df4,kind= "line")

# %%
sns.scatterplot(x = "age", y="fare",data = d)
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>

# %%
#barplot: bivariate
#x axis = "cat"
#y axis = "num"

# %%
sns.barplot(x = "survived",y= "age",data=d)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
d.groupby("survived")["age"].mean()
# Out:
# survived
# 0    30.626179
# 1    28.343690
# Name: age, dtype: float64

# %%
d.groupby("survived")["age"].max()
# Out:
# survived
# 0    74.0
# 1    80.0
# Name: age, dtype: float64

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x = "total_bill", y = "time", data =df )
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='time'>

# %%
sns.barplot(x = "sex", y = "tip", data =df, hue = "smoker")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x = "sex", y = "tip", data =df, hue = "smoker")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x = "sex", y = "total_bill", data =df )
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(x = "sex", y = "total_bill", data =df , dodge = False );

# %%
# categorical plotting

# %%
sns.catplot(x = 'sex',y= "tip",data = df)

# %%
df5 = sns.load_dataset("exercise")
df5
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
df5.drop(columns = ["Unnamed:0"],inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\GOURAV~1\AppData\Local\Temp/ipykernel_8220/3584298188.py in <module>
# ----> 1 df5.drop(columns = ["Unnamed:0"],inplace = True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
df5["time"].unique()
# Out:
# ['1 min', '15 min', '30 min']
# Categories (3, object): ['1 min', '15 min', '30 min']

# %%
df5["time"]=df5["time"].apply(lambda x:x.rstrip("min"))

# %%
df5["time"]
# Out:
# 0      1
# 1     15
# 2     30
# 3      1
# 4     15
#      ...
# 85    15
# 86    30
# 87     1
# 88    15
# 89    30
# Name: time, Length: 90, dtype: category
# Categories (3, object): ['1 ', '15 ', '30 ']

# %%
df5.columns
# Out:
# Index(['Unnamed: 0', 'id', 'diet', 'pulse', 'time', 'kind'], dtype='object')

# %%
sns.catplot(x = "sex",y = "tip", data =df , kind = "swarm",size = 7 );
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3750: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x = "sex",y = "tip", data =df ,size = 5 )
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.catplot ( x = "smoker", y = "total_bill", data = df , kind = "violin")

# %%
sns.catplot( x = "time" , y ="total_bill" , data = df, kind ="boxen")

# %%
sns.countplot(x = "day" , data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.pairplot(df);

# %%
sns.pairplot(df, kind = "kde");

# %%
sns.pairplot(df,kind = "hist");

# %%
sns.displot(df["total_bill"],kde = False)

# %%
sns.jointplot( x = "total_bill" , y ="tip" , data = df, kind ="hex")

# %%
sns.jointplot( x = "total_bill" , y ="tip" , data = df, kind ="kde")

# %%
sns.jointplot( x = "total_bill" , y ="tip" , data = df, kind ="resid")
