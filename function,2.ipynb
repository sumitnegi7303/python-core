# %%
managers = ["tornado","chieol"]
sales = [45,50]
batch_no = [12,34]
list(zip(managers,sales,batch_no))
# Out:
# [('tornado', 45, 12), ('chieol', 50, 34)]

# %%
countres = ["dubai","england"]
good = [54,52]
excelent = [53,46]
list(zip(countres,good,excelent))
# Out:
# [('dubai', 54, 53), ('england', 52, 46)]

# %%
a = "Dubai"
for i in a :
    print(ord(i),i)
max(a)
min(a)
# Out:
# 68 D
# 117 u
# 98 b
# 97 a
# 105 i
# 'D'

# %%
z = "England"
for i in z :
    print(ord(i),i)
max(z)
min(z)
# Out:
# 69 E
# 110 n
# 103 g
# 108 l
# 97 a
# 110 n
# 100 d
# 'E'

# %%
z = [24,4,4,524]
max(z)
# Out:
# 524

# %%
z = [23,3,6,4,5,3]
min(z)
# Out:
# 3

# %%
l = [1,2,3,4,5,6]
max(l)
# Out:
# 6

# %%
l = [1,3,4,34,5,56]
min(l)
# Out:
# 1

# %%
. required
. default
. keyword
. arbitary

# %%
#default:

# %%
def cel_feh(c=67):
    f = 9/5*c+32
    print(f)
    c1 = (f-32)*5/9
    print(c1)
cel_feh(25)
# Out:
# 77.0
# 25.0

# %%
def name (b,a="daf"):
    lname = "singh"
    print(lname,a,b)
name(b=31213)
# Out:
# singh daf 31213

# %%
#arbitary:

# %%
1)*args
2)**kwarys
keyword argument

# %%
def ar(*a):
    print(type(a))
    for i in a:
        print(i)
ar(23,23,4,'ssf',3,3435,335,3,4245)
# Out:
# <class 'tuple'>
# 23
# 23
# 4
# ssf
# 3
# 3435
# 335
# 3
# 4245

# %%
def ar(**a):
    print(type(a))
    for i in a:
        print(i)
ar(a=23,b=23,c=4,d='ssf',e=3,f=3435,g=3353,h=4245)
# Out:
# <class 'dict'>
# a
# b
# c
# d
# e
# f
# g
# h

# %%
def ar(**a):
    print(type(a))
    print(a)
    for i, in a:
        print(i,)
ar(a=23,b=23,c=4,d='ssf',e=3,f=3435,g=3353,h=4245)
# Out:
# <class 'dict'>
# {'a': 23, 'b': 23, 'c': 4, 'd': 'ssf', 'e': 3, 'f': 3435, 'g': 3353, 'h': 4245}
# a
# b
# c
# d
# e
# f
# g
# h

# %%
def square _value(num):

# %%
def fun():
    global z
    z = 10
    print(z)
fun()
z
# Out:
# 10
# 10
